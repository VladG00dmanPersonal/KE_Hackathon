# %%
import pandas as pd
import numpy as np
import csv
import json
from func import get_school

# %%
data = json.load(open("/workspaces/KE_Hackathon/Final_Hackathon_L2SH_26/app/static/task1_parse/parsed_results.json", "r", encoding="utf-8"))["Второй тур"]["300"]
df = pd.DataFrame(data)[[""]].sort_values("Итог", ascending=False).reset_index(drop=True)
# df['school'] = df['Участник'].apply(lambda x: get_school(x)[0])
# df["Место"] = df.index + 1
# df["Призёр"] = (df["Место"] <= 225) & (df["Место"] > 40)
# df["Победитель"] = df["Место"] <= 40
# df = df.dropna()
# df = df.groupby("school").agg(
#     Participants = ("Место", "count"),
#     Prized = ("Призёр", "sum"),
#     Winners = ("Победитель", "sum"),
#     MinPlace = ("Место", "min"),
#     MaxPlace = ("Место", "max"),
# ).reset_index().sort_values("Participants", ascending=False).reset_index(drop=True)
# df
df
# Out:
#     Место                        Участник                 Регион Класс  \
# 0       1         Грекова Дарья Сергеевна                 Москва    10
# 1       2       Абдуллин Гимран Маратович   Республика Татарстан    10
# 2     3-4        Пискарев Иван Викторович                 Москва    11
# 3     3-4       Устименко Глеб Витальевич                 Москва    11
# 4       5           Лосев Пётр Валерьевич                 Москва    10
# ..    ...                             ...                    ...   ...
# 372   373         Рафиков Тимур Ришатович   Астраханская область    11
# 373   374         Питаев Камиль Асиятович     Пензенская область    11
# 374   375  Морозов Владислав Владимирович      Псковская область    10
# 375   376    Харитонова Лилия Геннадиевна            Севастополь    10
# 376   377        Майтак Дмитрий Сергеевич  Новосибирская область    11
#
#     Задача 1 Задача 2 Задача 3 Задача 4 Итог
# 0        100      100      100       72  764
# 1        100      100      100       60  752
# 2        100      100      100       44  744
# 3        100      100      100       44  744
# 4        100      100      100       50  742
# ..       ...      ...      ...      ...  ...
# 372      100        .        .        .  139
# 373       32        0        .        .  132
# 374        .       16        .        .  116
# 375       44       16        0        .  104
# 376       32        .        .        4  100
#
# [377 rows x 9 columns]
