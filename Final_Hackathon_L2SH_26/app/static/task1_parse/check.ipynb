# %%
import pandas as pd
import numpy as np
import json

data = json.load(open("parsed_results.json", "r", encoding="utf-8"))["Второй тур"]["300"]
df = pd.DataFrame(data)[["Место", "Регион", "Итог"]].sort_values("Итог", ascending=False).reset_index(drop=True)
df["Место"] = df.index + 1
df["Призёр"] = (df["Место"] <= 225) & (df["Место"] > 40)
df["Победитель"] = df["Место"] <= 40
df = df.groupby("Регион").agg(
    Participants = ("Место", "count"),
    Prized = ("Призёр", "sum"),
    Winners = ("Победитель", "sum"),
    MinPlace = ("Место", "min"),
    MaxPlace = ("Место", "max"),
).reset_index().sort_values("Participants", ascending=False)
df.head(20)
# Out:
#                              Регион  Participants  Prized  Winners  MinPlace  \
# 28                           Москва           165      96       26         1
# 56                  Санкт-Петербург            26      12        6        16
# 52             Республика Татарстан            25      15        3         2
# 29               Московская область            19       7        0        47
# 73              Челябинская область            17       6        1        11
# 59             Свердловская область            15       6        0        63
# 38                    Пермский край             8       5        1        39
# 33            Новосибирская область             7       3        2         8
# 26                 Липецкая область             6       4        0        53
# 35             Оренбургская область             5       2        1        27
# 42          Республика Башкортостан             4       2        0        89
# 68            Удмуртская Республика             3       2        0       134
# 7               Вологодская область             3       1        0       208
# 57              Саратовская область             3       2        0       166
# 31            Нижегородская область             3       2        0       111
# 1             Архангельская область             2       0        0       246
# 8               Воронежская область             2       2        0        84
# 75  Ямало-ненецкий автономный округ             2       1        0       156
# 76              Ярославская область             2       1        0       191
# 22                Красноярский край             2       2        0        57
#
#     MaxPlace
# 28       366
# 56       311
# 52       324
# 29       337
# 73       359
# 59       346
# 38       276
# 33       377
# 26       313
# 35       342
# 42       282
# 68       244
# 7        319
# 57       273
# 31       364
# 1        277
# 8        140
# 75       237
# 76       285
# 22       182
